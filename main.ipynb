# %%
# Import library
from langchain_community.document_loaders import PyPDFLoader

# Create a document loader for bc_cat_2020.pdf
loader = PyPDFLoader('bc_cat_2020.pdf')

# Load the document
data = loader.load()
print(data[0])
# Out:
# page_content='BE INSPIRED
# B&C COLLECTION 2020
# BE INSPIRED
# WWW.BC-FASHION.EU
# WWW.BC-FASHION.EU
# © 2020 THE COTTON GROUP - ALL RIGHTS OF REPRODUCTION RESERVED IN ALL COUNTRIES AND FOR ALL TYPES OF MEDIA - DESIGN BY 2210.BE
# ENB&C Collection / The Cotton Group is member of:
# 2020 ISSUE JAN - DEC' metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 14.0 (Macintosh)', 'creationdate': '2019-12-13T13:04:00+01:00', 'moddate': '2019-12-20T13:55:23+01:00', 'title': '', 'trapped': '/False', 'source': 'bc_cat_2020.pdf', 'total_pages': 111, 'page': 0, 'page_label': '1'}

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import Document  # Import correctly
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter  # FIXED Import
import os

# Load the PDF document
loader = PyPDFLoader("bc_cat_2020.pdf")
document = loader.load()

# Define a text splitter
text_splitter = RecursiveCharacterTextSplitter(
    separators=['\n', '.', ' ', ''],
    chunk_size=75,  
    chunk_overlap=10  
)

# Split the document
chunks = text_splitter.split_documents(document)

print(chunks)
print([len(chunk.page_content) for chunk in chunks])
# Out:
# [Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 14.0 (Macintosh)', 'creationdate': '2019-12-13T13:04:00+01:00', 'moddate': '2019-12-20T13:55:23+01:00', 'title': '', 'trapped': '/False', 'source': 'bc_cat_2020.pdf', 'total_pages': 111, 'page': 0, 'page_label': '1'}, page_content='BE INSPIRED\nB&C COLLECTION 2020\nBE INSPIRED\nWWW.BC-FASHION.EU'), Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 14.0 (Macintosh)', 'creationdate': '2019-12-13T13:04:00+01:00', 'moddate': '2019-12-20T13:55:23+01:00', 'title': '', 'trapped': '/False', 'source': 'bc_cat_2020.pdf', 'total_pages': 111, 'page': 0, 'page_label': '1'}, page_content='WWW.BC-FASHION.EU'), Document(metadata={'producer': 'Adobe PDF Library 15.0', 'creator': 'Adobe InDesign CC 14.0 (Macintosh)', 'creationdate': '2019-12-13T13:04:00+01:00', 'moddate': '2019-12-20T13:55:23+01:00', 'title': '', 'trapped': '/False', 'source': 'bc_cat_2020.pdf', 'total_pages': 1
# ...

# %%
# Import the class for defining Hugging Face pipelines
from langchain_huggingface import HuggingFacePipeline

# Define the LLM from the Hugging Face model ID
llm = HuggingFacePipeline.from_model_id(
    model_id="crumb/nano-mistral",
    task="text-generation",
    pipeline_kwargs={"max_new_tokens": 100}
)

prompt = "Hugging Face is"

# Invoke the model
response = llm.invoke(prompt)
print(response)
# Out:
# Device set to use cpu
# Hugging Face is a great way to get a little bit of a break from the stresses of life. It's a great way to get a little bit of a break from the stresses of life.
#
# I'm a big fan of the "I'm a big fan of the show" approach. I've been a fan of the show for a long time, and I've always been a fan of the show. I've been a fan of the show for a long

# %%
response = llm.invoke(prompt, pipeline_kwargs={"max_new_tokens": 100, "temperature": 0.7})
print(response)
# Out:
# c:\Users\fomic\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\generation\configuration_utils.py:629: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.7` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# Hugging Face is a great way to get a little bit of a break from the stresses of life. It's a great way to get a little bit of a break from the stresses of life.
#
# I'm a big fan of the "I'm a big fan of the show" approach. I've been a fan of the show for a long time, and I've always been a fan of the show. I've been a fan of the show for a long

# %%
def generate_text(prompt):
    return llm.invoke(prompt, pipeline_kwargs={"max_new_tokens": 100})

# %%
try:
    response = llm.invoke(prompt)
    print(response)
except Exception as e:
    print(f"Error generating response: {e}")
# Out:
# Hugging Face is a great way to get a little bit of a break from the stresses of life. It's a great way to get a little bit of a break from the stresses of life.
#
# I'm a big fan of the "I'm a big fan of the show" approach. I've been a fan of the show for a long time, and I've always been a fan of the show. I've been a fan of the show for a long

# %%
llm = HuggingFacePipeline.from_model_id(
    model_id="t5-small",  # For summarization
    task="summarization"
)
# Out:
# Device set to use cpu

# %%
def query(payload):
    response = requests.post(api_url, headers=headers, json=payload)
    print("Response Status Code:", response.status_code)
    print("Response Content:", response.text)
    return response.json() if response.status_code == 200 else {}

# %%
def query(payload):
    response = requests.post(api_url, headers=headers, json=payload)
    print("Remaining API calls:", response.headers.get("X-RateLimit-Remaining"))
    return response.json() if response.status_code == 200 else {}

# %%
import os
import requests

# Set up the API endpoint
model_id = "gpt2"  # Replace with your model name if different
api_url = f"https://api-inference.huggingface.co/models/{model_id}"

# Set your Hugging Face API token
api_token = "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"  # Replace with your API token

headers = {
    "Authorization": f"Bearer {api_token}"
}

def query(payload):
    response = requests.post(api_url, headers=headers, json=payload)
    return response.json()

# Example usage
prompt = "Hugging Face is"
result = query({"inputs": prompt})
print(result)
# Out:
# [{'generated_text': "Hugging Face is beautiful, which is especially powerful when you feel your skin being simply, just take perfect light. It's easier to grow a healthy, straight beard or hose through stitches.\n\nLove this: Health, Beauty, Oral Aid, Training, Confidence"}]

# %%
prompt_1 = "What is the weather like in Brussels?"
result_1 = query({"inputs": prompt_1})
print(result_1)

prompt_2 = "Tell me about the history of AI."
result_2 = query({"inputs": prompt_2})
print(result_2)
# Out:
# [{'generated_text': 'What is the weather like in Brussels?\n\nIt is acrid. So Brody literally runs around in his spray! No feedback.\n\nWhere is right now?\n\nDoes anyone know what\'s going on here? Just want a news post here which seems to highlight the fact that it is too ooze, not under foot...it\'s just lookin\' at one side of Brussels (my guess is that it started out as overpriced gelatos...) tells you something about the colours waiting outside...it\'s |just a trendy place it is. I flew to the \'alexaaya del base\' (so I got the Glasber Kiss Gell Aparo de Zulker - inaugural mermaid hotel - one exchange !!!!) only to find out that it was designed to be spam. Fascinating stuff.\n\nWorking on the neon journals here. I\'m really excited.\n\nFor some reason, I\'m growing tearish. I would love to start collecting more neon markers from their talking up.\n\nAlright, good. I\'ve got to see him as soon as Powers comes back to speak with F0te but we\'ll stay the same. Fortunately he\'s a
# ...

# %%
import streamlit as st
import requests

api_url = "https://api-inference.huggingface.co/models/gpt2"
api_token = "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"
headers = {"Authorization": f"Bearer {api_token}"}

def query(payload):
    response = requests.post(api_url, headers=headers, json=payload)
    return response.json()

st.title("Hugging Face GPT-2 Inference")

user_input = st.text_input("Enter your prompt:")

if user_input:
    result = query({"inputs": user_input})
    st.write(result)
# Out:
# 2025-02-28 22:51:45.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-28 22:51:45.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-28 22:51:45.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-28 22:51:45.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-28 22:51:45.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-28 22:51:45.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-28 22:51:45.527 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
